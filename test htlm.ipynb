# %%
# %%html
#
# <img src=F://PrimeSuspects//PrimeSuspects//scr//Picture30.png>
# <img src="F:\\PrimeSuspects\\PrimeSuspects\\scr\\Picture30.png" />
# <!-- <img src=Picture30.png> -->
# Out:
# <img src=F://PrimeSuspects//PrimeSuspects//scr//Picture30.png>
# <img src="F:\\PrimeSuspects\\PrimeSuspects\\scr\\Picture30.png" />
# <!-- <img src=Picture30.png> -->

# %% [markdown]
# # mark down cell
# # md"![image](Picture30.png)"

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 62CC-5E33
#
#  Directory of C:\Users\cash_\Desktop\nb
#
# 2024-11-11  08:49 AM    <DIR>          .
# 2024-11-11  08:49 AM    <DIR>          ..
# 2024-11-11  08:41 AM    <DIR>          .ipynb_checkpoints
# 2024-11-11  08:42 AM    <DIR>          .jupyter
# 2024-11-11  08:43 AM    <DIR>          nb
# 2024-11-11  08:49 AM            10,399 test htlm.ipynb
#                1 File(s)         10,399 bytes
#                5 Dir(s)  1,217,799,974,912 bytes free

# %%
# %%html
# https://cashfields.github.io/PrimeSuspects/html/Chapter%200090%20Make%20The%20fam.html
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#   <head>
#     <meta charset='utf-8'>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=640">
#
#     <link rel="stylesheet" href="/PrimeSuspects/assets/css/style.css?v=1e4f71d01cfe3d1ccafdb3464b6e0bebab472687" media="screen">
#     <link rel="stylesheet" href="/PrimeSuspects/assets/css/mobile.css" media="only screen and (max-width:640px)">
#     <link rel="stylesheet" href="/PrimeSuspects/assets/css/non-screen.css" media="only screen and (max-width:640px)">
#
#     <script src="/PrimeSuspects/assets/js/modernizr.js"></script>
#     <script src="https://code.jquery.com/jquery-1.12.4.min.js" integrity="sha256-ZosEbRLbNQzLpnKIkEdrPv7lOy9C27hHQ+Xp8a4MxAQ=" crossorigin="anonymous"></script>
#     <script src="/PrimeSuspects/assets/js/headsmart.min.js"></script>
#     <script>
#       $(document).ready(function () {
#         $('#main_content').headsmart()
#       })
#     </script>
#
# ...
